# %%
import pandas as pd

# %%
df = pd.read_csv("chicago_crime_df.csv", parse_dates=[2])

# %%
df['date'] = pd.DatetimeIndex(df.t).normalize()
# Out:
# Timestamp('2003-01-24 16:21:45+0000', tz='UTC')

# %%
df['date_bin'] = pd.cut(df['date'],bins=1000)
df.groupby('date_bin').count()['iucr'].plot()

# %%
df['month'] = df['date'].apply(lambda d : d.month)

# %%
newDf = df.set_index('date').resample('D').count()

# %%
newDF.plot()
# Out:
# C:\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:1172: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   "will drop timezone information.", UserWarning)

# %%
tempDf = pd.read_csv("Chicago Midway Airport 2000-2019.csv", parse_dates=[2])

# %%
tempDf['AVG'] = (tempDf['TMAX'] + tempDf['TMIN']) / 2

# %%
newTempDf = tempDf.set_index('DATE').resample('M').mean()['AVG']

# %%
newTempDf.plot()

# %%
tempDf
# Out:
#           STATION                           NAME       DATE  TAVG  TMAX  TMIN  \
# 0     USW00014819  CHICAGO MIDWAY AIRPORT, IL US 2000-01-01  43.0  50.0  35.0
# 1     USW00014819  CHICAGO MIDWAY AIRPORT, IL US 2000-01-02  49.0  61.0  37.0
# 2     USW00014819  CHICAGO MIDWAY AIRPORT, IL US 2000-01-03  38.0  41.0  34.0
# 3     USW00014819  CHICAGO MIDWAY AIRPORT, IL US 2000-01-04  29.0  34.0  23.0
# 4     USW00014819  CHICAGO MIDWAY AIRPORT, IL US 2000-01-05  22.0  27.0  16.0
# 5     USW00014819  CHICAGO MIDWAY AIRPORT, IL US 2000-01-06  35.0  43.0  27.0
# 6     USW00014819  CHICAGO MIDWAY AIRPORT, IL US 2000-01-07  27.0  30.0  23.0
# 7     USW00014819  CHICAGO MIDWAY AIRPORT, IL US 2000-01-08  38.0  46.0  29.0
# 8     USW00014819  CHICAGO MIDWAY AIRPORT, IL US 2000-01-09  40.0  42.0  37.0
# 9     USW00014819  CHICAGO MIDWAY AIRPORT, IL US 2000-01-10  44.0  47.0  40.0
# 10    USW00014819  CHICAGO MIDWAY AIRPORT, IL US 2000-01-11  35.0  39.0  30.0
# ...

# %%
df['DATE'] = df['date']
df.DATE = pd.to_datetime(df.DATE)
tempDf.DATE = pd.to_datetime(tempDf.DATE)

df['temp']= df['DATE'].merge(tempDf,how='left').AVG
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-a9f43801f02e> in <module>
#       2 df.DATE = pd.to_datetime(df.DATE)
#       3 tempDf.DATE = pd.to_datetime(tempDf.DATE)
# ----> 4 df['temp']= df['DATE'].merge(tempDf,how='left').AVG
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'merge'

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
ts = pd.Series(df["primary_type"], index=df["date"]).cumsum().plot()
